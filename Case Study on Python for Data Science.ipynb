# %% [markdown]
# # CASE STUDY IN PYTHON FOR DATA SCIENCE

# %% [markdown]
# A telephone company wishes to investigate their customer churn count.
# The company wants to check the following facts.

# %%
import pandas as pd

# %%
data=pd.read_excel(r"C:\Users\kavya\Downloads\Telco-Customer-Churn.xlsx")
# Out:
# C:\Users\kavya\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# 1] The number of customers owns their connection based on :
# a. Gender
# b. Citizenship

# %%
data1=pd.crosstab(data["Churn"],data["gender"])
data1.iloc[0]
# Out:
# gender
# Female    2549
# Male      2625
# Name: No, dtype: int64

# %%
data2=pd.crosstab(data["Churn"],data["SeniorCitizen"])
data2.iloc[0]
# Out:
# SeniorCitizen
# 0    4508
# 1     666
# Name: No, dtype: int64

# %% [markdown]
# 2]The number of customers left their service:
# a. Gender
# b. Citizenship

# %%
data3=pd.crosstab(data["Churn"],data["gender"])
data3.iloc[1]
# Out:
# gender
# Female    939
# Male      930
# Name: Yes, dtype: int64

# %%
data4=pd.crosstab(data["Churn"],data["SeniorCitizen"])
data4.iloc[1]
# Out:
# SeniorCitizen
# 0    1393
# 1     476
# Name: Yes, dtype: int64

# %% [markdown]
# 3] Preference of payment method based on :
# a. Churn
# b. Contract

# %%
pd.crosstab(data["PaymentMethod"],data["Churn"])
# Out:
# Churn                        No   Yes
# PaymentMethod
# Bank transfer (automatic)  1286   258
# Credit card (automatic)    1290   232
# Electronic check           1294  1071
# Mailed check               1304   308

# %%
pd.crosstab(data["Contract"],data["PaymentMethod"])
# Out:
# PaymentMethod   Bank transfer (automatic)  Credit card (automatic)  \
# Contract
# Month-to-month                        589                      543
# One year                              391                      398
# Two year                              564                      581
#
# PaymentMethod   Electronic check  Mailed check
# Contract
# Month-to-month              1850           893
# One year                     347           337
# Two year                     168           382

# %% [markdown]
# 4]Internet service preference by gender based on churn status.

# %%
pd.crosstab([data.InternetService,data.Churn],data.gender,margins=False)
# Out:
# gender                 Female  Male
# InternetService Churn
# DSL             No        969   993
#                 Yes       219   240
# Fiber optic     No        889   910
#                 Yes       664   633
# No              No        691   722
#                 Yes        56    57

# %% [markdown]
# 5]Explain the descriptive statistics of “TotalCharges” based on:
# a. Gender
# b. Contract
# c. Payment Method

# %%
data5=data["TotalCharges"]
data5.groupby(data.gender).describe()
# Out:
#          count         mean          std    min      25%      50%        75%  \
# gender
# Female  3488.0  2289.338308  2276.695359  18.85  403.300  1389.05  3834.0625
# Male    3555.0  2291.680667  2273.095299  18.80  399.275  1406.00  3778.1000
#
#             max
# gender
# Female  8672.45
# Male    8684.80

# %%
data6=data["TotalCharges"]
data6.groupby(data.Contract).describe()
# Out:
#                  count         mean          std    min       25%      50%  \
# Contract
# Month-to-month  3875.0  1369.254581  1613.879008  18.85   160.100   679.55
# One year        1473.0  3038.377461  2233.477741  18.80   989.450  2658.40
# Two year        1695.0  3746.752383  2582.454154  20.35  1280.125  3638.25
#
#                     75%      max
# Contract
# Month-to-month  2066.50  8061.50
# One year        4860.35  8684.80
# Two year        6044.30  8672.45

# %%
data7=data["TotalCharges"]
data7.groupby(data.PaymentMethod).describe()
# Out:
#                             count         mean          std    min        25%  \
# PaymentMethod
# Bank transfer (automatic)  1544.0  3083.566023  2360.362773  19.25  1052.3875
# Credit card (automatic)    1522.0  3074.920894  2410.536742  19.30   989.4000
# Electronic check           2365.0  2090.868182  2155.435320  18.85   308.0500
# Mailed check               1612.0  1083.236973  1509.101844  18.80   116.9375
#
#                                 50%        75%      max
# PaymentMethod
# Bank transfer (automatic)  2479.500  4948.3375  8684.80
# Credit card (automatic)    2454.175  5016.5500  8670.10
# Electronic check           1253.900  3340.5500  8564.75
# Mailed check                473.675  1316.0000  8476.50
